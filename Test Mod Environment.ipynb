# %%
import sys

sys.path.append(r'C:/Users/faria/PycharmProjects/simglucose_mod')
import simglucose

# %%
import gym

# Register gym environment. By specifying kwargs,
# you are able to choose which patient to simulate.
# patient_name must be 'adolescent#001' to 'adolescent#010',
# or 'adult#001' to 'adult#010', or 'child#001' to 'child#010'
from gym.envs.registration import register
register(
    id='simglucose-adolescent2-v0',
    entry_point='simglucose.envs:ModT1DSimEnv',
    kwargs={'patient_name': 'adolescent#001'}
)

env = gym.make('simglucose-adolescent2-v0')
# Out:
# C:\Users\faria\anaconda3\lib\site-packages\gym\envs\registration.py:17: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
import numpy as np

# %%
# import simglucose.envs.mod_simglucose_gym_env

# %%
# from simglucose.controller.basal_bolus_ctrller import BBController

# controller = BBController()

# %%
from simglucose.controller.bolus_controller import BolusController

controller = BolusController(cr=1.0, cf=1.0)

# %%
observation, reward, done, info = env.reset()

# %%
tot_reward = 0
for t in range(28800):
    env.render()
    
    action = controller.policy(observation, reward, done, patient_name='adolescent#001', meal=info['meal'])
    print(action)
    
    observation, reward, done, info = env.step(action)
    tot_reward += reward
    if done:
        print("Episode finished after {} timesteps".format(t + 1))
        break
# Out:
# C:\Users\faria\PycharmProjects\simglucose_mod\simglucose\simulation\mod_env.py:174: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df['CHO'] = pd.Series(self.CHO_hist)
# C:\Users\faria\PycharmProjects\simglucose_mod\simglucose\simulation\mod_env.py:175: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df['insulin'] = pd.Series(self.insulin_hist)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ctrller_action(basal=0, bolus=0.0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4864/886050169.py in <module>
#       1 tot_reward = 0
#       2 for t in range(28800):
# ----> 3     env.render()
#       4
#       5     action = controller.policy(observation, reward, done, patient_name='adolescent#001', meal=info['meal'])
#
# ~\anaconda3\lib\site-packages\gym\core.py in render(self, mode, close)
#     148             elif mode not in modes:
#     149                 raise error.UnsupportedMode('Unsupported rendering mode: {}. (Supported modes for {}: {})'.format(mode, self, modes))
# --> 150         return self._render(mode=mode, close=close)
#     151
#     152     def close(self):
#
# ~\PycharmProjects\simglucose_mod\simglucose\envs\mod_simglucose_gym_env.py in _render(self, mode, close)
#      73
#      74     def _render(self, mode='human', close=False):
# ---> 75         self.env.render(close=close)
#      76
#      77     @property
#
# ~\PycharmProjects\simglucose_mod\simglucose\simulation\mod_env.py in render(self, close)
#     165             self.viewer = Viewer(self.scenario.start_time, self.patient.name)
#     166
# --> 167         self.viewer.render(self.show_history())
#     168
#     169     def show_history(self):
#
# ~\PycharmProjects\simglucose_mod\simglucose\simulation\rendering.py in render(self, data)
#     114         adjust_xlim(self.axes[3], data.index[-1], xlabel=True)
#     115
# --> 116         self.update()
#     117
#     118     def close(self):
#
# ~\PycharmProjects\simglucose_mod\simglucose\simulation\rendering.py in update(self)
#      63
#      64     def update(self):
# ---> 65         self.fig.canvas.draw()
#      66         self.fig.canvas.flush_events()
#      67
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      71     @wraps(draw)
#      72     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73         result = draw(artist, renderer, *args, **kwargs)
#      74         if renderer._rasterizing:
#      75             renderer.stop_rasterizing()
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2808
#    2809             self.patch.draw(renderer)
# -> 2810             mimage._draw_list_compositing_images(
#    2811                 renderer, self, artists, self.suppressComposite)
#    2812
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer)
#    3080             renderer.stop_rasterizing()
#    3081
# -> 3082         mimage._draw_list_compositing_images(
#    3083             renderer, self, artists, self.figure.suppressComposite)
#    3084
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\legend.py in draw(self, renderer)
#     626
#     627         self.legendPatch.draw(renderer)
# --> 628         self._legend_box.draw(renderer)
#     629
#     630         renderer.close_group('legend')
#
# ~\anaconda3\lib\site-packages\matplotlib\offsetbox.py in draw(self, renderer)
#     364         for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     365             c.set_offset((px + ox, py + oy))
# --> 366             c.draw(renderer)
#     367
#     368         bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#
# ~\anaconda3\lib\site-packages\matplotlib\offsetbox.py in draw(self, renderer)
#     357         to the given *renderer*.
#     358         """
# --> 359         width, height, xdescent, ydescent, offsets = self.get_extent_offsets(
#     360                                                         renderer)
#     361
#
# ~\anaconda3\lib\site-packages\matplotlib\offsetbox.py in get_extent_offsets(self, renderer)
#     470         sep = self.sep * dpicor
#     471
# --> 472         whd_list = [c.get_extent(renderer)
#     473                     for c in self.get_visible_children()]
#     474
#
# ~\anaconda3\lib\site-packages\matplotlib\offsetbox.py in <listcomp>(.0)
#     470         sep = self.sep * dpicor
#     471
# --> 472         whd_list = [c.get_extent(renderer)
#     473                     for c in self.get_visible_children()]
#     474
#
# ~\anaconda3\lib\site-packages\matplotlib\offsetbox.py in get_extent(self, renderer)
#     343     def get_extent(self, renderer):
#     344         """Return a tuple ``width, height, xdescent, ydescent`` of the box."""
# --> 345         w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
#     346         return w, h, xd, yd
#     347
#
# ~\anaconda3\lib\site-packages\matplotlib\offsetbox.py in get_extent_offsets(self, renderer)
#     434                     c.set_width(self.width)
#     435
# --> 436         whd_list = [c.get_extent(renderer)
#     437                     for c in self.get_visible_children()]
#     438         whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
#
# ~\anaconda3\lib\site-packages\matplotlib\offsetbox.py in <listcomp>(.0)
#     434                     c.set_width(self.width)
#     435
# --> 436         whd_list = [c.get_extent(renderer)
#     437                     for c in self.get_visible_children()]
#     438         whd_list = [(w, h, xd, (h - yd)) for w, h, xd, yd in whd_list]
#
# ~\anaconda3\lib\site-packages\matplotlib\offsetbox.py in get_extent(self, renderer)
#     343     def get_extent(self, renderer):
#     344         """Return a tuple ``width, height, xdescent, ydescent`` of the box."""
# --> 345         w, h, xd, yd, offsets = self.get_extent_offsets(renderer)
#     346         return w, h, xd, yd
#     347
#
# ~\anaconda3\lib\site-packages\matplotlib\offsetbox.py in get_extent_offsets(self, renderer)
#     470         sep = self.sep * dpicor
#     471
# --> 472         whd_list = [c.get_extent(renderer)
#     473                     for c in self.get_visible_children()]
#     474
#
# ~\anaconda3\lib\site-packages\matplotlib\offsetbox.py in <listcomp>(.0)
#     470         sep = self.sep * dpicor
#     471
# --> 472         whd_list = [c.get_extent(renderer)
#     473                     for c in self.get_visible_children()]
#     474
#
# ~\anaconda3\lib\site-packages\matplotlib\offsetbox.py in get_extent(self, renderer)
#     807
#     808     def get_extent(self, renderer):
# --> 809         _, h_, d_ = renderer.get_text_width_height_descent(
#     810             "lp", self._text._fontproperties,
#     811             ismath="TeX" if self._text.get_usetex() else False)
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     268         flags = get_hinting_flag()
#     269         font = self._get_agg_font(prop)
# --> 270         font.set_text(s, 0.0, flags=flags)
#     271         w, h = font.get_width_height()  # width and height of unrotated string
#     272         d = font.get_descent()
#
# KeyboardInterrupt:

# %%
tot_reward
